# %%
class School:
    def __init__(self):
        self.con=sqlite3.connect("school_management.db")
        self.c=self.con.cursor()
        self.c.execute("Create Table if not exists Teacher(name text, age int, mobile int, salary int, subject text, id int, email text, password int)")
        self.c.execute("Create Table if not exists Student(name text, age int, class text, mobile int, father text, mother text, id int, email text, password int)")
        self.c.execute("Create Table if not exists Course(id int, course text, grades text)")
        self.con.commit()
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
    def enter_data(self):
        def teacher():
            def add_teacher():
                while True:
                    Email=input("Enter your Email ID : ")
                    self.c.execute("SELECT email from Teacher")
                    print()
                    emailrecords=[i[0] for i in self.c.fetchall()]
                    if Email not in emailrecords:
                        break
                    else:
                        print("\nEmail ID Already Exists!\n")
                while True:
                    Password=int(g.getpass("\nEnter Password in Numeric Numbers : "))
                    confirm_password=int(g.getpass("Re-enter Password in Numeric Numbers : "))
                    if Password==confirm_password:
                        break
                    else:
                        print("\nPassword Not Match!\n")
                Name=input("\nEnter Your Name : ")
                Age=int(input("Enter Your Age : "))
                Mobile=int(input("Enter Your Mobile Number : "))
                Salary=float(input("Enter Your Salary Amount "))
                Subject=input("Enter Your Subject Name : ")
                Id=np.random.randint(1000,9999)
                print()
                self.c.execute("Insert into Teacher (name, age, mobile, salary, subject, id, email, password) values (?,?,?,?,?,?,?,?)",(Name,Age,Mobile,Salary,Subject,Id,Email,Password))
                self.con.commit()
                print("\nData Add Successfully\n")
            def update_teacher():
                print()
                self.c.execute("select id , password from Teacher")
                data=self.c.fetchall()
                ID=int(input("Enter Your ID : "))
                password=int(g.getpass("Enter Your Password : "))
                x=1
                for i in data:
                    if i[0]==ID and i[1]==password:
                        print()
                        while True:
                            x=int(input("Press 1 for name , 2 for age , 3 for mobile , 4 for Salary , 5 for Subject , 6 for Email-ID & 7 for Password : "))
                            if x==1:
                                Name=input("\nEnter Your New Name : ")
                                self.c.execute("Update Teacher set name = (?) where id = (?)",(Name,ID,))
                                print("Name Updated Successfully")
                                print()
                            elif x==2:
                                Age=input("\nEnter Your New age : ")
                                self.c.execute("Update Teacher set age = (?) where id = (?)",(Age,ID,))
                                print("Age Updated Successfully")
                                print()
                            elif x==3:
                                Mobile=input("\nEnter Your New Mobile Number : ")
                                self.c.execute("Update Teacher set mobile = (?) where id = (?)",(Mobile,ID,))
                                print("Mobile Updated Successfully")
                                print()
                            elif x==4:
                                Salary=input("\nEnter Your New Salary : ")
                                self.c.execute("Update Teacher set salary = (?) where id = (?)",(Salary,ID,))
                                print("Salary Updated Successfully")
                                print()
                            elif x==5:
                                Subject=input("\nEnter Your New Subject : ")
                                self.c.execute("Update Teacher set subject = (?) where id = (?)",(Subject,ID,))
                                print("Subject Updated Successfully")
                                print()
                            elif x==6:
                                Email=input("\nEnter Your New Email-ID : ")
                                self.c.execute("Update Teacher set email = (?) where id = (?)",(Email,ID,))
                                print("Email-ID Updated Successfully")
                                print()
                            elif x==7:
                                Password=input("\nEnter Your New Password : ")
                                self.c.execute("Update Teacher set password = (?) where id = (?)",(Password,ID,))
                                print("Password Updated Successfully")
                                print()
                            else:
                                break
                        self.con.commit()
                        x=0
                if x==1:
                    print("\nWrong Credential\n")
            def delete_teacher():
                ID=int(input("\nEnter Your ID : "))
                Password=int(input("Enter Your Password : "))
                self.c.execute("select id,password from Teacher")
                data=self.c.fetchall()
                x=1
                for i in data:
                    if i[0]==ID and i[1]==Password:
                        self.c.execute("delete from Teacher where id = (?)",(ID,))
                        print("\nInformation Deleted Successfully")
                        x=0
                if x==1:
                    print("\nWrong Credential!\n")
            def show_teacher():
                print()
                Email=int(input("\nEnter Your Email ID : "))
                Password=int(input("Enter Your Password : "))
                self.c.execute("select email,password from Teacher")
                data=self.c.fetchall()
                x=1
                for i in data:
                    if i[0]==Email and i[1]==Password:
                        print("\nYour Data is : ")
                        self.c.execute("Select * from Teacher where email= (?)",(email,))
                        sys=self.c.fetchall()
                        for i in sys:
                            print("\t\tName     : ",i[0])
                            print("\t\tAge      : ",i[1])
                            print("\t\tMobile   : ",i[2])
                            print("\t\tSalary   : ",i[3])
                            print("\t\tSubject  : ",i[4])
                            print("\t\tID       : ",i[5])
                            print("\t\tEmail    : ",i[6])
                            print("\t\tPassword : ",i[7])
                            print()
                        x=0
                if x==1:
                    print("\nWrong Credential!\n")
            while True:
                print("\nPress 1 for Add Teacher Data")
                print("Press 2 for Update Teacher Data")
                print("Press 3 for Delete Teacher Data")
                print("Press 4 for Show Teacher Data\n")
                x=int(input("Press a key : "))
                if x==1:
                    add_teacher()
                elif x==2:
                    update_teacher()
                elif x==3:
                    delete_teacher()
                elif x==4:
                    show_teacher()
                else:
                    break
#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
        def student():
            def add_student():
                while True:
                    Email=input("\nEnter Your Email ID : ")
                    self.c.execute("Select email from Student")
                    emailrecords=[i[0] for i in self.c.fetchall()]
                    if Email not in emailrecords:
                        break
                    else:
                        print("\nEmail ID Already Exists\n")
                while True:
                    Password=int(g.getpass("\nEnter Password in Numeric Numbers : "))
                    confirm_password=int(g.getpass("Re-enter Password in Numeric Numbers : "))
                    if Password==confirm_password:
                        break
                    else:
                        print("\nPassword Not Match!\n")
                Name=input("\nEnter Your Name : ")
                Age=int(input("Enter Your Age : "))
                Class=input("Enter Your Class : ")
                Mobile=int(input("Enter Your Mobile Number : "))
                Father=input("Enter Your Father Name : ")
                Mother=input("Enter Your Mother Name : ")
                ID=np.random.randint(1000000,9999999)
                self.c.execute("INSERT into Student (name,age,class,mobile,father,mother,id,email,password) values (?,?,?,?,?,?,?,?,?)",(Name,Age,Class,Mobile,Father,Mother,ID,Email,Password))
                self.con.commit()
                print("\nInformation Recieve Successfully\n")
            def update_student():
                print()
                self.c.execute("select id , password from Student")
                data=self.c.fetchall()
                ID=int(input("Enter Your ID : "))
                password=int(g.getpass("Enter Your Password : "))
                x=1
                for i in data:
                    if i[0]==ID and i[1]==password:
                        print()
                        while True:
                            x=int(input("Press 1 for name , 2 for age , 3 for class , 4 for mobile , 5 for father , 6 for mother , 7 for email-id & 8 for Password : "))
                            if x==1:
                                Name=input("\nEnter Your New Name : ")
                                self.c.execute("Update Student set name = (?) where id = (?)",(Name,ID,))
                                print("Name Updated Successfully")
                                print()
                            elif x==2:
                                Age=input("\nEnter Your New age : ")
                                self.c.execute("Update Student set age = (?) where id = (?)",(Age,ID,))
                                print("Age Updated Successfully")
                                print()
                            elif x==3:
                                Class=input("\nEnter Your New Class : ")
                                self.c.execute("Update Student set class = (?) where id = (?)",(Class,ID,))
                                print("Class Updated Successfully")
                                print()
                            elif x==4:
                                Mobile=input("\nEnter Your Mobile : ")
                                self.c.execute("Update Student set mobile = (?) where id = (?)",(Mobile,ID,))
                                print("Mobile Updated Successfully")
                                print()
                            elif x==5:
                                Father=input("\nEnter Your Father Name : ")
                                self.c.execute("Update Student set father = (?) where id = (?)",(Father,ID,))
                                print("Father Name Updated Successfully")
                                print()
                            elif x==6:
                                Mother=input("\nEnter Your Mother Name : ")
                                self.c.execute("Update Student set mother = (?) where id = (?)",(Mother,ID,))
                                print("Mother Updated Successfully")
                                print()
                            elif x==7:
                                Email=input("\nEnter Your New Email-ID : ")
                                self.c.execute("Update Student set email = (?) where id = (?)",(Email,ID,))
                                print("Email-ID Updated Successfully")
                                print()
                            elif x==8:
                                Password=input("\nEnter Your New Password : ")
                                self.c.execute("Update Student set password = (?) where id = (?)",(Password,ID,))
                                print("Password Updated Successfully")
                                print()
                            else:
                                break
                        self.con.commit()
                        x=0
                if x==1:
                    print("\nWrong Credential\n")
            def delete_student():
                ID=int(input("\nEnter Your ID : "))
                Password=int(input("Enter Your Password : "))
                self.c.execute("select id,password from Student")
                data=self.c.fetchall()
                x=1
                for i in data:
                    if i[0]==ID and i[1]==Password:
                        self.c.execute("delete from Student where id = (?)",(ID,))
                        self.con.commit()
                        print("\nInformation Deleted Successfully")
                        x=0
                if x==1:
                    print("\nWrong Credential!\n")
            def show_students():
                print()
                Email=int(input("\nEnter Your Email ID : "))
                Password=int(input("Enter Your Password : "))
                self.c.execute("select email,password from Student")
                data=self.c.fetchall()
                x=1
                for i in data:
                    if i[0]==Email and i[1]==Password:
                        print("\nYour Data is : ")
                        self.c.execute("Select * from Student where email= (?)",(email,))
                        sys=self.c.fetchall()
                        for i in sys:
                            print("\t\tName       : ",i[0])
                            print("\t\tAge        : ",i[1])
                            print("\t\tClass      : ",i[2])
                            print("\t\tMobile     : ",i[3])
                            print("\t\tFather     : ",i[4])
                            print("\t\tMother     : ",i[5])
                            print("\t\tStudent-ID : ",i[6])
                            print("\t\tEmail-ID   : ",i[7])
                            print("\t\tPassword   : ",i[8])
                            print()
                        x=0
                if x==1:
                    print("\nWrong Credential!\n")
            while True:
                print("\nPress 1 for Add Student Data")
                print("Press 2 for Update Student Data")
                print("Press 3 for Delete Student Data")
                print("Press 4 for Show Student Data\n")
                x=int(input("Press a key : "))
                if x==1:
                    add_student()
                elif x==2:
                    update_student()
                elif x==3:
                    delete_student()
                elif x==4:
                    show_students()
                else:
                    break
        while True:
            print("\nPress 1 for Enter Teacher Data")
            print("Press 2 for Enter Student Data")
            print("Press 3 for Enter Exit!")
            x=int(input("Press a key : "))
            if x==1:
                teacher()
            elif x==2:
                student()
            elif x==3:
                break
            else:
                print("Wrong Input!")
#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
    def student_course(self):
        def course_details():
            print()
            self.c.execute("Select subject from Teacher")
            Subject=input("Enter Subject Name")
            subjectrecords=[i[0] for i in self.c.fetchall()]
            x=1
            if Subject in subjectrecords:
                self.c.execute("Select * from Teacher where subject = (?)",(Subject,))
                data=self.c.fetchall()
                print("\nYour Data : ")
                for i in data:
                    print("\t\tName       : ",i[0])
                    print("\t\tMobile     : ",i[2])
                    print("\t\tSubject    : ",i[4])
                    print("\t\tStudent-ID : ",i[5])
                    print("\t\tEmail      : ",i[6])
                    print()
                x=0
            if x==1:
                print(f"\nSorry, Currently We don't have Teacher for this Subject - {Subject} ")
                print()
        def student_course():
            def add_course():
                ID=int(input("\nEnter Student ID : "))
                course_name=input("Enter Student Course Name : ")
                self.c.execute("select subject from Teacher")
                records=[i[0] for i in self.c.fetchall()]
                if course_name in records:
                    self.c.execute("Insert into Course (id,course) values (?,?)",(ID,course_name,))
                    self.con.commit()
                    print("\nCourse Add Successfully\n")
                else:
                    print(f"\nSorry, Currently We don't have Teacher for this Course - {course_name} ")
            def update_grades():
                ID=int(input("\nEnter Student ID : "))
                course_name=input("Enter Course Name : ")
                self.c.execute("Select * from Course where id = (?) and course = (?)",(ID,course_name,))
                data=self.c.fetchone()
                if data:
                    Grade=input("\nEnter Grade : ")
                    self.c.execute("Update Course set grades = (?) where id = (?)",(Grade,ID,))
                    self.con.commit()
                    print("Grade Updated Successfully\n")
                else:
                    print("\nNo Course Found for this Student!\n")
            def show_grades():
                ID=int(input("\nEnter Student ID : "))
                self.c.execute("Select * from Course")
                data=self.c.fetchall()
                x=1
                for i in data:
                    if i[0]==ID:
                        print("\nYour Data is : ")
                        self.c.execute("select * from Course where id = (?)",(ID,))
                        sys=self.c.fetchall()
                        for i in sys:
                            print("\t\tStudent-ID  : ",i[0])
                            print("\t\tCourse Name : ",i[1])
                            print("\t\tGrades      : ",i[2])
                            print()
                        x=0
                if x==1:
                    print("\nNo Data Found!\n")
                    
                    
            while True:
                x=int(input("Press 1 for Add Course , 2 for Update_Grades & 3 for Show Grades : "))
                if x==1:
                    add_course()
                elif x==2:
                    update_grades()
                elif x==3:
                    show_grades()
                else:
                    break
        while True:
            print("\nPress 1 for Course Details")
            print("Press 2 for Student Course")
            x=int(input("\nPress a key : "))
            if x==1:
                course_details()
            elif x==2:
                student_course()
            else:
                break
########################################################################################################################################################################################################################################################################################################################
import sqlite3
import numpy as np
import getpass as g
s=School()
print("\t\t\t\tWelcome TO the School Management System")
School_ID=123
School_Password=123
x=int(input("\nEnter School ID : "))
y=int(g.getpass("Enter School Password : "))
if x==School_ID and y==School_Password:
    while True:
        print("\nPress 1 for Enter Data")
        print("Press 2 for Student Course Details")
        print("Press 3 for Exit!")
        x=int(input("Press a Key : "))
        if x==1:
            print()
            s.enter_data()
        elif x==2:
            print()
            s.student_course()
        else:
            print("\nThanks")
            break
else:
    print("\nSorry, Wrong Credential Found!")
    print("Plase Try AGain Later!")
# Out:
# 				Welcome TO the School Management System
# Enter School ID :  1
# Enter School Password :  ········
# Sorry, Wrong Credential Found!
# Plase Try AGain Later!
